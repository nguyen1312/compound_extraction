# %% [markdown]
# ## Import Python Package and Library

# %%
import textwrap
from rapidfuzz import fuzz
import os, glob2, json
from typing import List, Dict, Optional
from fastprogress import progress_bar
import chromadb
from langchain_chroma import Chroma
from chromadb.config import Settings
from chromadb.utils import embedding_functions
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from sentence_transformers import SentenceTransformer
from typing import Any
import requests
import logging
import pandas as pd
from fastapi import FastAPI, HTTPException
import shutil
import time
from Dolphin.demo_page_hf import *
import warnings
warnings.filterwarnings('ignore')
# from huggingface_hub import notebook_login
# notebook_login()
# Out:
# Skipping import of cpp extensions due to incompatible torch version 2.9.0+cu128 for torchao version 0.13.0

# %%
import getpass
if not os.environ.get("GEMINI_API_KEY"):
  os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter API key for Gemini: ")
GEMINI_API_KEY = os.environ.get("GEMINI_API_1KEY")
# Out:
# Enter API key for Gemini:  ········

# %% [markdown]
# ## Content Extraction from PDF file

# %%
class Args:
    max_batch_size = 16
    model_path = "Dolphin/hf_model/"
    save_dir = "./output/labeled_test/"
    input_path = "./dataset/labeled_test/"

# %%
args = Args()
# Load Model
model_parse_document = DOLPHIN(args.model_path)
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# The module name  (originally ) is not a valid Python identifier. Please rename the original module to avoid import issues.

# %%
def extract_context_md(args):
    if os.path.isdir(args.save_dir) == False:
        if os.path.isdir(args.input_path):
            # Support both image and PDF files
            file_extensions = [".pdf", ".PDF"]
            document_files = []
            for ext in file_extensions:
                document_files.extend(glob.glob(os.path.join(args.input_path, f"*{ext}")))
            document_files = sorted(document_files)
        else:
            if not os.path.exists(args.input_path):
                raise FileNotFoundError(f"Input path {args.input_path} does not exist")
            
            # Check if it's a supported file type
            file_ext = os.path.splitext(args.input_path)[1].lower()
            supported_exts = ['.pdf']
            
            if file_ext not in supported_exts:
                raise ValueError(f"Unsupported file type: {file_ext}. Supported types: {supported_exts}")
            
            document_files = [args.input_path]
        
        save_dir = args.save_dir or (
            args.input_path if os.path.isdir(args.input_path) else os.path.dirname(args.input_path)
        )
        setup_output_dirs(save_dir)
        total_samples = len(document_files)
        print(f"\nTotal files to process: {total_samples}")
        # Process All Document Files
        for file_path in document_files:
            print(f"\nProcessing {file_path}")
            try:
                start = time.perf_counter()  # high precision timer
                json_path, recognition_results = process_document(
                    document_path=file_path,
                    model=model_parse_document,
                    save_dir=save_dir,
                    max_batch_size=args.max_batch_size,
                )
        
                print(f"Processing completed. Results saved to {save_dir}")
                end = time.perf_counter()

                latency_ms = (end - start) * 1000
                print(f"Latency document extraction: {latency_ms:.2f} ms")
                        
            except Exception as e:
                print(f"Error processing {file_path}: {str(e)}")
                continue
    parsed_dataset = glob2.glob(f"{args.save_dir}/markdown/*.md")
    return parsed_dataset

# %% [markdown]
# ## Pipeline Retrieval Augmented Generation (RAG) for Compounds Extraction

# %% [markdown]
# ### Embedding Module

# %%
class CustomEmbedding:
    def __init__(self, emb_model, device="cuda"):
        self.model = emb_model
    def _embed(self, texts: list[str]) -> list[list[float]]:
        vectors = self.model.encode_document(texts)
        return vectors.tolist()

    def embed_documents(self, texts: list[str]) -> list[list[float]]:
        return self._embed(texts)

    def embed_query(self, text: str) -> list[float]:
        return self._embed([text])[0]

# %% [markdown]
# ### Storing Document using Langchain API for Document storage

# %%
def add_documents(docs: list[dict], vectorstore):
    # Configure the splitter
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=800,      # max tokens/characters per chunk
        chunk_overlap=200,   # overlap between chunks
        separators=["\n\n", "\n", " ", ""]
    )
    langchain_docs = []
    for d in docs:
        chunks = text_splitter.split_text(d["text"])
        for idx, chunk in enumerate(chunks):
            langchain_docs.append(
                Document(
                    page_content=chunk,
                    metadata={**d.get("metadata", {}), "source_id": d["id"], "chunk_index": idx}
                )
            )
    vectorstore.add_documents(langchain_docs)
    print(f"[ingest] Added {len(langchain_docs)} chunks to Chroma (LangChain).")
    return len(langchain_docs)

# %% [markdown]
# ### Gemini API Call

# %%
GEMINI_API_KEY="" # insert here
assert GEMINI_API_KEY != "", "Provide API Key"
GEMINI_MODEL = "gemini-2.5-pro"

# %%
# ==== function to call Gemini generateContent API ====
def call_gemini_generate(prompt: str, context: List[Dict[str, Any]] = None) -> str:
    url = f"https://generativelanguage.googleapis.com/v1beta/models/{GEMINI_MODEL}:generateContent"
    headers = {
        "Content-Type": "application/json",
        "x-goog-api-key": GEMINI_API_KEY,
    }

    # Build contents list
    contents = []
    # system message (if desired)
    contents.append({
        "role": "user",
        "parts": [
            {"text": "You are a helpful assistant."}
        ]
    })
    # add any context messages
    if context:
        for msg in context:
            contents.append({
                "role": msg["role"],
                "parts": [{"text": msg["content"]}]
            })
    # then user prompt
    contents.append({
        "role": "user",
        "parts": [{"text": prompt}]
    })

    data = {
        "contents": contents
    }
    resp = requests.post(url, json=data, headers=headers)
    if resp.status_code != 200:
        raise HTTPException(status_code=500, detail=f"Gemini generateContent error: {resp.text}")

    respjson = resp.json()
    # According to docs: response has candidates → content → parts → text
    # Extract the assistant content (first candidate)
    try:
        candidate = respjson["candidates"][0]
        content = candidate["content"]
        # Sometimes there are multiple parts
        parts = content.get("parts", [])
        texts = [p.get("text", "") for p in parts]
        answer = "".join(texts)
        return answer
    except Exception as e:
        raise HTTPException(status_code=500, detail=f"Error parsing Gemini response: {respjson}")

# %% [markdown]
# ### Information retrieval using LLM , i.e., Gemini API

# %%
def answer_query(user_query, vectorstore, k=30):
    print("------ RAG latency----------")
    start = time.perf_counter()  # high precision timer

    retriever = vectorstore.as_retriever(search_kwargs={"k": k})
    docs = retriever.get_relevant_documents(user_query)

    context = "\n\n".join(
        [f"[source {d.metadata['source_id']} chunk {d.metadata['chunk_index']}]\n{d.page_content}" for d in docs]
    )
    # print(context)
    prompt = textwrap.dedent(f"""
        Use the following retrieved context to answer the question.
        If the query is extract all compounds of document, extract all compounds, each compound including the following fields with precise information from the text provided.
        Return lists of JSON objects, each JSON object exactly (no surrounding explanation) with these keys:
        - compound_name: string or null # e.g, Ajubractin A, 15-Hydroxyajubractin C
        - species: string or null  # Latin name or common name of the plant, e.g, Ajuga bracteosa, Aronia melanocarpa L
        - organism: string or null # e.g. leaves, root, seed , Aerial parts
        - amount: string or null   # amount with units, e.g. 3.2 mg/g dry weight , 0.5% (w/w), 
            Route 1: N/A,Route 2: Fraction 90F2: 10.6 mg; Fraction 90E: 10.0 mg.,
            Route 1: 34 mg Route 2: 4.7 mg
        If a field cannot be found, set it to N/A. 
        Context:
        {context}
        Question:
        {user_query}
        Answer (concise):
    """)
    end = time.perf_counter()
    latency_ms = (end - start) * 1000
    print(f"Latency indexing: {latency_ms:.2f} ms")
    start = time.perf_counter()  # high precision timer
    output_gemini = call_gemini_generate(prompt)
    end = time.perf_counter()
    latency_ms = (end - start) * 1000
    print(f"Latency call API Gemini: {latency_ms:.2f} ms")
    print("------ RAG latency----------")
    return output_gemini

# %% [markdown]
# ### Evaluation with Groundtruth

# %%
# ----------------------------- Evaluation ------------------------------------
def canonicalize(s: Optional[str]) -> Optional[str]:
    if s is None:
        return None
    return re.sub(r"\s+", " ", s.strip().lower())
    
def compute_metrics(pred: Dict[str, Any], gold: Dict[str, Any]) -> Dict[str, float]:
    """Compute simple precision/recall/F1 per field (binary: match or not) and micro averages.
    For amount and compound names, fuzzy matching threshold.
    """
    fields = ["compound_name", "species", "organism", "amount"]
    tp = fp = fn = 0
    per_field = {}
    for f in fields:
        p = pred.get(f)
        g = gold.get(f)
        p_c = canonicalize(p)
        g_c = canonicalize(g)
        match = False
        if g_c is None:
            # if gold is missing, ignore field in metrics
            per_field[f] = None
            continue
        if p_c is None:
            match = False
        else:
            if f in ["compound_name", "organism"]:
                score = fuzz.token_sort_ratio(p_c, g_c)
                match = score >= 80
            elif f == "amount":
                # numeric tolerance. compare numbers and unit substring
                nump = re.search(r"([0-9.]+)", p_c or "")
                numg = re.search(r"([0-9.]+)", g_c or "")
                if nump and numg:
                    try:
                        a = float(nump.group(1))
                        b = float(numg.group(1))
                        match = abs(a - b) / max(abs(b), 1e-6) <= 0.2  # within 20%
                        # also require unit substring
                        match = match and ("mg" in p_c or "%" in p_c) == ("mg" in g_c or "%" in g_c)
                    except Exception:
                        match = False
                else:
                    match = fuzz.token_sort_ratio(p_c, g_c) >= 85
            else:
                match = p_c == g_c
        if match:
            tp += 1
            per_field[f] = 1
        else:
            fp += 1
            fn += 1
            per_field[f] = 0
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0.0
    per_field['precision'] = precision
    per_field['recall'] = recall
    per_field['f1'] = f1
    return per_field
    
def evaluation_accuracy(sample_pred, sample_gt):
    key_map_dict = {'Name':'compound_name','Species':'species', 'Organisms': 'organism', 'Amount of molecule': 'amount'}
    sample_gt_update = list(map(lambda xx: {(key_map_dict[k] if k in key_map_dict else k):v  for (k,v) in xx.items()}, sample_gt))
    gt_name_candidates = list(map(lambda x: x["compound_name"], sample_gt_update))
    pred_name_candidates = list(map(lambda x: x["compound_name"], sample_pred))
    perf_total = list()
    gt_pred = list()
    for sample in sample_pred:
        eval_checks = list(map(lambda x: compute_metrics(sample, x), sample_gt_update))
        list_scoring = np.array(list(map(lambda x: np.sum(np.array(list(x.values())[-3:])), eval_checks)))
        argmax_score = np.argmax(list_scoring)
        respective_gt = sample_gt_update[argmax_score]
        perf = eval_checks[argmax_score]
        perf_total.append(perf)
        gt_pred.append({"gt": respective_gt, "pred": sample})
    precision_list = list(map(lambda x: x["precision"], perf_total))
    recall_list = list(map(lambda x: x["recall"], perf_total))
    f1_list = list(map(lambda x: x["f1"], perf_total))
    print("Macro Avg. Precision: ", np.mean(np.array(precision_list)))
    print("Macro Avg. Recall: ", np.mean(np.array(recall_list)))
    print("Macro Avg. F1 score: ", np.mean(np.array(f1_list)))
    df_perf = pd.DataFrame({"Macro Avg. Precision":np.mean(np.array(precision_list)),
                             "Macro Avg. Recall":np.mean(np.array(recall_list)),
                             "Macro Avg. F1 score":np.mean(np.array(f1_list))}, index=[0])
    return gt_pred, perf_total, df_perf

# %% [markdown]
# ## Inference

# %% [markdown]
# ### Labeled Test

# %%
# init embedding instance
emb_model = SentenceTransformer("google/embeddinggemma-300m")
embedding_fn = CustomEmbedding(emb_model)
# contents
class Args:
    max_batch_size = 16
    model_path = "Dolphin/hf_model/"
    save_dir = "./output/labeled_test/"
    input_path = "./dataset/labeled_test/"
args = Args()
parsed_dataset = extract_context_md(args)
groundtruth = list()
prediction = list()
for markdown_file in progress_bar(parsed_dataset):
    # ------------------ Example Usage -----------------
    with open(markdown_file, "r", encoding="utf-8") as f:
        markdown_content = f.read()
    name_document = markdown_file.split("/")[-1].split(".")[0]
    print(f"Process: {name_document}")
    print("-" * 100)
    start = time.perf_counter()
    chroma_path = f"chroma_db/chromadb_{name_document}"   # persistent path for Chroma
    vectorstore = Chroma(
        collection_name="science_document",
        persist_directory=chroma_path,
        embedding_function=embedding_fn 
    )
    if vectorstore._collection.count() == 0:
        sample_docs = [
            {"id": f"{name_document}", "text": markdown_content}
        ]
        len_chunks = add_documents(sample_docs, vectorstore)
    else:
        len_chunks = vectorstore._collection.count()
    end = time.perf_counter()
    latency_ms = (end - start) * 1000
    print(f"Latency init custom db: {latency_ms:.2f} ms")
    query_input = "Extract all compounds of document"
    start = time.perf_counter()
    str_result_json = answer_query(query_input, k=len_chunks, vectorstore=vectorstore).replace("json", "")
    end = time.perf_counter()
    latency_ms = (end - start) * 1000
    print(f"Latency extraction: {latency_ms:.2f} ms")
    
    json_str = str_result_json.strip().lstrip("\ufeff")
    output_data = json.loads(json_str.replace("```", "").replace("\n", ""))
    if args.input_path.find("/labeled_test") != -1:
        gt_path = f"{args.input_path}/groundtruth/{name_document}.json"
        assert os.path.exists(gt_path) == True, "Bug"
        gt_anno = json.load(open(gt_path, "r"))
        groundtruth.append(gt_anno)
        prediction.append(output_data)
        data_check, _, perf = evaluation_accuracy(output_data, gt_anno)
        print()
        gt1 = data_check[-4]["gt"]
        pred1 = data_check[-4]["pred"]
        print(f"Sample: GT: {gt1}, Prediction: {pred1}")
        data_df_check = pd.DataFrame.from_dict(data_check)
        data_df_check.to_csv("labeled_test_result_review.csv")
        perf.to_csv(f"acc_{name_document}.csv")
# Out:
# Total files to process: 2
#
# Processing ./dataset/labeled_test/J Sci Food Agric - 1999 - Zlatanov - Lipid composition of Bulgarian chokeberry  black currant and rose hip seed oils.pdf
# Successfully converted 5 pages from PDF
# Processing page 1/5
# Processing page 2/5
# Processing page 3/5
# Processing page 4/5
# Processing page 5/5
# Processing completed. Results saved to ./output/labeled_test/
# Latency document extraction: 41597.92 ms
#
# Processing ./dataset/labeled_test/coll-et-al-2011-neo-clerodane-diterpenoids-from-ajuga-bracteosa.pdf
# Successfully converted 6 pages from PDF
# Processing page 1/6
# Processing page 2/6
# Processing page 3/6
# Processing page 4/6
# Processing page 5/6
# Processing page 6/6
# Processing completed. Results saved to ./output/labeled_test/
# Latency document extraction: 52622.17 ms
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 02:40&lt;00:00]
#     </div>
# Process: J Sci Food Agric - 1999 - Zlatanov - Lipid composition of Bulgarian chokeberry  black currant and rose hip seed oils
# ----------------------------------------------------------------------------------------------------
# Latency init custom db: 85.00 ms
# ------ RAG latency----------
# Latency indexing: 114.19 ms
# Latency call API Gemini: 108998.47 ms
# ------ RAG latency----------
# Latency extraction: 109113.05 ms
# Macro Avg. Precision:  0.24523809523809523
# Macro Avg. Recall:  0.24523809523809523
# Macro Avg. F1 score:  0.24523809523809523
#
# Sample: GT: {'compound_name': 'δ-Tocopherol', 'species': 'Rosa canina L', 'organism': 'seeds', 'amount': '1.8 mg/kg'}, Prediction: {'compound_name': 'δ-Tocopherol', 'species': 'Rose hip', 'organism': 'seed oil', 'amount': '1.8 % of total tocopherols'}
# Process: coll-et-al-2011-neo-clerodane-diterpenoids-from-ajuga-bracteosa
# ----------------------------------------------------------------------------------------------------
# [ingest] Added 66 chunks to Chroma (LangChain).
# Latency init custom db: 650.60 ms
# ------ RAG latency----------
# Latency indexing: 27.56 ms
# Latency call API Gemini: 50819.14 ms
# ------ RAG latency----------
# Latency extraction: 50847.07 ms
# Macro Avg. Precision:  0.953125
# Macro Avg. Recall:  0.953125
# Macro Avg. F1 score:  0.953125
#
# Sample: GT: {'compound_name': '15-Hydroxyajubractin C', 'species': 'Ajuga bracteosa', 'organism': 'Aerial parts', 'amount': '3.1 mg'}, Prediction: {'compound_name': '15-hydroxyajubractin C', 'species': 'Ajuga bracteosa', 'organism': 'Aerial parts', 'amount': '3.1 mg'}

# %% [markdown]
# ### Unlabeled_Test

# %%
def build_self_eval_prompt(document_text: str, extracted_json: str) -> str:
    return f"""
    You are a scientific information auditor. 
    Your task is to evaluate how well the following JSON extraction matches the information present in the document text.
    
    ---
    DOCUMENT TEXT:
    {document_text}
    ---
    
    EXTRACTED JSON:
    {extracted_json}
    ---
    
    Evaluate each field by:
    1. Checking if the information appears and matches the document.
    2. Rating accuracy (0–1).
    3. Explaining reasoning briefly.
    4. Providing an overall extraction quality score (0–1).
    
    Return a JSON report in the following format:
    {{
      "field_scores": {{
        "Compound Name": float,
        "Species": float,
        "Organism": float,
        "Amount of Molecule": float
      }},
      "field_feedback": {{
        "Compound Name": str,
        "Species": str,
        "Organism": str,
        "Amount of Molecule": str
      }},
      "overall_score": float,
      "overall_feedback": str
    }}
    """
import json

def validate_answer(document_text: str, extracted_json: List[dict]):
    results = list()
    for js in extracted_json:
        prompt = build_self_eval_prompt(document_text, json.dumps(extracted_json, indent=2))
        response = call_gemini_generate(prompt).replace("json", "")
        json_str = response.strip().lstrip("\ufeff")
        try:
            result = json.loads(json_str.replace("```", "").replace("\n", ""))
        except json.JSONDecodeError:
            result = {"raw_response": json_str.replace("```", "").replace("\n", "")}
        results.append(result)
    return results

# %%
# contents
class Args:
    max_batch_size = 16
    model_path = "Dolphin/hf_model/"
    save_dir = "./output/unlabeled_test/"
    input_path = "./dataset/unlabeled_test/"
args = Args()
parsed_dataset = extract_context_md(args)
groundtruth = list()
prediction = list()
for markdown_file in progress_bar(parsed_dataset):
    # ------------------ Example Usage -----------------
    with open(markdown_file, "r", encoding="utf-8") as f:
        markdown_content = f.read()
    name_document = markdown_file.split("/")[-1].split(".")[0]
    print(f"Process: {name_document}")
    print("-" * 100)
    chroma_path = f"chroma_db/chromadb_{name_document}"   # persistent path for Chroma
    vectorstore = Chroma(
        collection_name="science_document",
        persist_directory=chroma_path,
        embedding_function=embedding_fn 
    )
    if vectorstore._collection.count() == 0:
        sample_docs = [
            {"id": f"{name_document}", "text": markdown_content}
        ]
        len_chunks = add_documents(sample_docs, vectorstore)
    else:
        len_chunks = vectorstore._collection.count()
        
    query_input = "Extract all compounds of document"
    try:
        str_result_json = answer_query(query_input, k=len_chunks, vectorstore=vectorstore).replace("json", "")
    except:
        GEMINI_MODEL = "gemini-2.5-flash" 
        str_result_json = answer_query(query_input, k=len_chunks, vectorstore=vectorstore).replace("json", "")
        
    json_str = str_result_json.strip().lstrip("\ufeff")
    output_data = json.loads(json_str.replace("```", "").replace("\n", ""))
    if args.input_path.find("/labeled_test") != -1:
        gt_path = f"{args.input_path}/groundtruth/{name_document}.json"
        assert os.path.exists(gt_path) == True, "Bug"
        gt_anno = json.load(open(gt_path, "r"))
        groundtruth.append(gt_anno)
        prediction.append(output_data)
        data_check, _ = evaluation_accuracy(output_data, gt_anno)
        print()
        gt1 = data_check[-4]["gt"]
        pred1 = data_check[-4]["pred"]
        print(f"Sample: GT: {gt1}, Prediction: {pred1}")
        data_df_check = pd.DataFrame.from_dict(data_check)
        data_df_check.to_csv("labeled_test_result_review.csv")
    else:
        try:
            resp = validate_answer(markdown_content, output_data)
        except:
            GEMINI_MODEL = "gemini-2.5-flash" 
            time.sleep(60)
            resp = validate_answer(markdown_content, output_data)
        df_result = pd.DataFrame.from_dict(output_data)
        df_result.to_csv(f"Gemni_Scoring__{name_document}_compounds_extraction.csv")
        with open(f"Gemni_Scoring__{name_document}_compounds_extraction.txt", "w") as ff:
            for r, o in zip(resp, output_data):
                ff.write(f"{str(o)}\t\t{r}\n")
        print("A criterion sample: ", resp[0])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='6' class='' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       54.55% [6/11 1:22:04&lt;1:08:23]
#     </div>
# Process: 00c735fc8eb3dee1b6497b89b04ae7d4-toxins5081392
# ----------------------------------------------------------------------------------------------------
# ------ RAG latency----------
# Latency indexing: 30.85 ms
# Latency call API Gemini: 10702.22 ms
# ------ RAG latency----------
# A criterion sample:  {'field_scores': {'Compound Name': 1.0, 'Species': 1.0, 'Organism': 1.0, 'Amount of Molecule': 1.0}, 'field_feedback': {'Compound Name': 'All extracted compound names (all-E-lutein, tyrosylproline anhydride) are precisely as stated in the document.', 'Species': 'All extracted species names (Dalbergia latifolia, Streptomyces) are precisely as stated in the document as the source organisms.', 'Organism': 'All extracted organism/source parts (leaves, culture filtrate) are precisely as stated in the document.', 'Amount of Molecule': "The amount for tyrosylproline anhydride (3 mg) is correctly extracted. 'N/A' for all-E-lutein is accurate as no specific isolated amount is mentioned for it in the text."}, 'overall_score': 1.0, 'overall_feedback': 'The JSON extraction is highly accurate and perfectly matches the information present in the document text for the identified inhibitors and their sources/amounts. Every field in both entries is correctly extracted and verified.'}
# Process: 0b64d0c9183530a5eb7f7e8f9cc60a2f-s-2008-1074496
# ----------------------------------------------------------------------------------------------------
# ------ RAG latency----------
# Latency indexing: 28.77 ms
# Latency call API Gemini: 63825.12 ms
# ------ RAG latency----------
# A criterion sample:  {'field_scores': {'Compound Name': 0.98, 'Species': 1.0, 'Organism': 0.95, 'Amount of Molecule': 0.98}, 'field_feedback': {'Compound Name': "Compound names are almost perfectly extracted, including their numerical identifiers. A very minor discrepancy exists for compound 10, where 'p-methoxy-(E)-cinnamoyl' is extracted as 'p-methoxy-(E)-cinnamoyl' instead of '[p-methoxy-(E)-cinnamoyl]'. This is a minor formatting difference that does not affect identification.", 'Species': 'All species information is accurately extracted and correctly associated with the respective compounds. The text clearly distinguishes between compounds isolated from Aloe vera, Aloe nobilis, and Aloe arborescens, and this distinction is perfectly captured.', 'Organism': "The extraction of organism parts is largely accurate. Where the document specifies 'dried leaves' for Aloe nobilis, it is correctly extracted. For Aloe vera and Aloe arborescens, where only 'extract' or 'plant' is mentioned without a specific part, 'N/A' is appropriately used. One minor point: for Aloe vera, the text mentions 'ethanolic extract', so 'N/A' for the organism part is reasonable as no specific botanical part (e.g., leaves) is detailed for the initial extraction from A. vera, unlike A. nobilis.", 'Amount of Molecule': "Amounts are extracted with high accuracy. All specified numerical amounts are correct, and 'N/A' is appropriately used when no amount is provided in the document for certain compounds or species. The distinction for compounds extracted from multiple species (e.g., compound 3 and 13) with different amounts or missing amounts is also handled well."}, 'overall_score': 0.97, 'overall_feedback': "The overall extraction quality is excellent. The JSON accurately captures compound names, associated species, and quantitative information (amounts) where available. The handling of 'N/A' for missing information, particularly for organism parts and amounts not specified in the text, demonstrates a thorough and intelligent extraction process. Minor discrepancies are negligible and do not impact the utility or accuracy of the extracted data."}
# Process: 0bd3f18ffd92e5f25b58cc4c70dc0e1e-np0401720
# ----------------------------------------------------------------------------------------------------
# [ingest] Added 58 chunks to Chroma (LangChain).
# ------ RAG latency----------
# Latency indexing: 31.45 ms
# Latency call API Gemini: 13690.44 ms
# ------ RAG latency----------
# A criterion sample:  {'field_scores': {'Compound Name': 1.0, 'Species': 1.0, 'Organism': 1.0, 'Amount of Molecule': 0.889}, 'field_feedback': {'Compound Name': "All compound names are correctly extracted and match the document text. For '7-acetoxybonducellpin C', the JSON uses the name from the introduction, which is consistent with the compound's identity, despite the experimental section listing '7-acetylbonducellpin C'.", 'Species': "The species 'Caesalpinia crista Linn.' is accurately identified and consistently applied to all extracted compounds.", 'Organism': "The organism part 'seed kernels' is correctly identified as the source material for all compounds.", 'Amount of Molecule': "Two amounts are incorrectly calculated based on the sum of multiple isolation mentions in the 'Extraction and Isolation' section: \n- 'caesalpinin D' was extracted as a total of 6.7 mg (0.8 mg + 5.9 mg), but the JSON lists 10.5 mg.\n- '2-acetoxycaesaldekarin e' was extracted as a total of 10.9 mg (6.0 mg + 4.9 mg), but the JSON lists 13.7 mg.\nThe 'N/A' entry for 'caesalpinin E' is correct as no amount is specified in the text. All other amounts are accurate."}, 'overall_score': 0.972, 'overall_feedback': "The extraction demonstrates a high level of accuracy for compound names, species, and organism source. However, it exhibits minor deficiencies in the calculation of total 'Amount of Molecule' for two compounds that were isolated in multiple fractions, leading to incorrect summations. This indicates a strong ability to identify and categorize information but a slight weakness in performing cumulative quantitative calculations from segmented textual data."}
# Process: 0d5340808c611f9cd52e1797fdd7835b-p19880000823
# ----------------------------------------------------------------------------------------------------
# [ingest] Added 105 chunks to Chroma (LangChain).
# ------ RAG latency----------
# Latency indexing: 29.12 ms
# Latency call API Gemini: 73321.71 ms
# ------ RAG latency----------
# A criterion sample:  {'field_scores': {'Compound Name': 0.975, 'Species': 1.0, 'Organism': 1.0, 'Amount of Molecule': 0.987}, 'field_feedback': {'Compound Name': "The compound name '(E)-methyl 3-(4-methoxyphenyl)propenoate' is extracted as present in the document's experimental section, but the document itself (via a footnote) indicates this name was 'Incorrectly named... in ref. 5.' and uses '(E)-methyl 3-(4-methoxyphenoxy)propenoate' in other contexts. The name 'x \\u03b2 -unsaturated ketone (3)' should correctly be '\\u03b1\\u03b2-unsaturated ketone (3)', indicating a character encoding or transcription error for the Greek letter alpha. For 'Desuccinoylpunctaporonin C (9)', while the descriptive name is present in a section header, the text itself refers to the compound as 'the triol (9)', which would be a more direct match.", 'Species': "All species names are accurately extracted and correctly marked as 'N/A' when the compound is a reaction product or synthesized material.", 'Organism': "All organism sources are accurately extracted and correctly marked as 'N/A' when the source is not specified or the compound is a reaction product/synthesized material.", 'Amount of Molecule': "For 'Punctaporonin D' and 'Punctaporonin B', the extracted amount '420 mg' refers to a mixture of punctaporonins B and D, as stated in the text ('yielded a mixture of punctaporonins B and D (420 mg)'). This value is incorrectly attributed as an individual amount for both compounds, rather than a quantity of a combined mixture."}, 'overall_score': 0.99, 'overall_feedback': "The extraction is of high quality, with most fields matching the document text perfectly. Minor issues include an inconsistency in a compound name due to the document's own self-correction, a character encoding issue for a Greek letter, and the misattribution of a mixture's total amount to individual components for two compounds. The extraction correctly handles 'N/A' for fields not explicitly present or when a compound is a reaction product/starting material rather than an isolated metabolite."}
# Process: 0f290f38960024792a0d2f9992f3b674-2803_252900251-4
# ----------------------------------------------------------------------------------------------------
# [ingest] Added 64 chunks to Chroma (LangChain).
# ------ RAG latency----------
# Latency indexing: 29.58 ms
# Latency call API Gemini: 101825.30 ms
# ------ RAG latency----------
# A criterion sample:  {'field_scores': {'Compound Name': 1.0, 'Species': 0.5, 'Organism': 0.7, 'Amount of Molecule': 0.9}, 'field_feedback': {'Compound Name': 'All compound names are accurately extracted and perfectly match the document text.', 'Species': "For the eight main pyrimidine metabolites (Uracil, Thymine, DHU, DHT, β-UP, β-UIB, β-Ala, β-AIB), 'N/A' is incorrectly assigned. The 'amount' values for these compounds are primarily derived from 'human urine', indicating 'human' as the relevant species. For the internal standards and 5-Fluorouracil, 'N/A' is correctly assigned.", 'Organism': "For the eight main pyrimidine metabolites, 'human urine' is a reasonable general context for the study. However, this designation is overgeneralized for specific entries within the 'amount' field that refer to chemical properties (e.g., molecular mass), stock solutions, or calibration ranges, where 'N/A' would be more appropriate. For internal standards and 5-Fluorouracil, 'N/A' is correctly assigned.", 'Amount of Molecule': "The 'amount' field is highly comprehensive, extracting a vast amount of quantitative and descriptive data for each compound. However, minor inaccuracies were noted, including:\n- Incorrect day counts for some urine stability data in Table 7 (e.g., '3 days' instead of '5 days' for bacteriuria urine, and omitting the '2 days' empty cell for β-UIB).\n- A missing 'added' value for one spiked urine sample (Uracil, Urine 3 in Table 6, where the document has '–').\n- Some redundancy, such as 'Amount for limits of quantitation' being listed in addition to 'LOQ'."}, 'overall_score': 0.78, 'overall_feedback': "The extraction demonstrates a strong capability in accurately identifying compound names and gathering a highly comprehensive set of associated quantitative data. The 'Amount of Molecule' field is particularly impressive in its detail, despite a few minor errors related to specific table entries (e.g., day counts, missing values). However, the 'Species' and 'Organism' fields suffer from overgeneralization or incorrect defaults, especially for the main analytes, where 'N/A' is used when 'human' or 'human urine' would be more appropriate or where a single value cannot accurately represent the diverse contexts of the extracted amounts (e.g., chemical properties vs. biological samples). Improving the contextual specificity for 'Species' and 'Organism' would significantly enhance the overall quality."}
# Process: 0f9fbaf3ae2c5092062b51cdec9f75e6-cpb1953
# ----------------------------------------------------------------------------------------------------
# [ingest] Added 31 chunks to Chroma (LangChain).
# ------ RAG latency----------
# Latency indexing: 28.27 ms
# Latency call API Gemini: 30893.48 ms
# ------ RAG latency----------
# A criterion sample:  {'field_scores': {'Compound Name': 1.0, 'Species': 0.96, 'Organism': 1.0, 'Amount of Molecule': 0.92}, 'field_feedback': {'Compound Name': 'All compound names listed in the JSON precisely match those found in the document text. The extraction is comprehensive and accurate for this field.', 'Species': "One minor inaccuracy was identified. For 'Erythromycin-carbomycin group substances', the extraction correctly identifies 'S. eurocidicus' but misses 'Nocardia mesenterica', which is stated as the 'first azomycin – producing strain' also producing a substance of this group. All other species extractions are accurate.", 'Organism': "This field is accurately extracted. 'N/A' is appropriately used when the origin is not specified or when the compound is a synthesized derivative rather than obtained from a biological source.", 'Amount of Molecule': "Two instances of missing quantitative information were found. For 'Silver Salt of Azomycin', the melting point ('m.p. over 300°') and the elemental analysis percentages (e.g., C, H, N, Ag percentages) should have been included. For 'Eurocidin', its characteristic UV absorption maxima ('318, 333, and 351 m $\\mu$') represent quantitative spectroscopic data that could be included under 'amount', similar to azomycin's solubility data."}, 'overall_score': 0.97, 'overall_feedback': "The extraction is of high quality, demonstrating strong accuracy in identifying compound names and their associated species and organisms. The main area for improvement lies in the comprehensive extraction of quantitative data for the 'Amount of Molecule' field, specifically including melting points, elemental analysis percentages, and spectroscopic characteristics when available, aligning with the extraction of solubilities for other compounds."}
# Process: 1ae1e00506d7b457df53b816a8e5a059-slct
# ----------------------------------------------------------------------------------------------------
# [ingest] Added 31 chunks to Chroma (LangChain).
# ------ RAG latency----------
# Latency indexing: 27.07 ms
# Latency call API Gemini: 94965.20 ms
# ------ RAG latency----------

# %% [markdown]
# ## End
